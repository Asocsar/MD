# %% [markdown]
# # Meta Methods applied to the ionosphere data set

# %%
import numpy as np                     # Llibreria matemÃ tica
import matplotlib.pyplot as plt        # Per mostrar plots
import sklearn                         # Llibreia de DM
import sklearn.datasets as ds            # Per carregar mÃ©s facilment el dataset digits
import sklearn.model_selection as cv    # Pel Cross-validation
import sklearn.neighbors as nb           # Per fer servir el knn
from sklearn.model_selection import cross_val_score  
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
data = pd.read_csv('games_clean.csv')

# %%
for name in data.columns[1:]:
    print("Before", name + '\n', data[data[name].isna()][name])
    data[name].fillna(data[name].mean(), inplace=True)
    print("After", name + '\n', data[data[name].isna()][name])
data.describe(include= 'all')
# Out:
# Before Indie
#  Series([], Name: Indie, dtype: bool)
# After Indie
#  Series([], Name: Indie, dtype: bool)
# Before Presence
#  Series([], Name: Presence, dtype: float64)
# After Presence
#  Series([], Name: Presence, dtype: float64)
# Before Memory
#  5      NaN
# 12     NaN
# 21     NaN
# 39     NaN
# 50     NaN
#         ..
# 2111   NaN
# 2112   NaN
# 2124   NaN
# 2126   NaN
# 2156   NaN
# Name: Memory, Length: 226, dtype: float64
# After Memory
#  Series([], Name: Memory, dtype: float64)
# Before ReleaseDate
#  519    NaN
# 696    NaN
# 752    NaN
# 857    NaN
# 1272   NaN
# 1404   NaN
# 1705   NaN
# 1721   NaN
# Name: ReleaseDate, dtype: float64
# After ReleaseDate
#  Series([], Name: ReleaseDate, dtype: float64)
# Before Soundtrack
#  Series([], Name: Soundtrack, dtype: bool)
# After Soundtrack
#  Series([], Name: Soundtrack, dtype: bool)
# Before OriginalCost
#  77     NaN
# 100    NaN
# 111    NaN
# 140    NaN
# 162    NaN
# 206    NaN
# 211    NaN
# 265    NaN
# 340    NaN
# 351    NaN
# 382    NaN
# 391    NaN
# 396    NaN
# 445    NaN
# 487    NaN
# 556    NaN
# 562    NaN
# 729    NaN
# 732    NaN
# 760    NaN
# 813    NaN
# 877    NaN
# 886    NaN
# 916    NaN
# 936    NaN
# 1002   NaN
# 1006   NaN
# 1078   NaN
# 1122   NaN
# 1179   NaN
# 1188   NaN
# 1191   NaN
# 1206   NaN
# 1263   NaN
# 1314   NaN
# 1328   NaN
# 1371   NaN
# 1385   NaN
# 1396   NaN
# 1406   NaN
# 1421   NaN
# 1465   NaN
# 1520   NaN
# 1536   NaN
# 1589   NaN
# 1605   NaN
# 1706   NaN
# 1739   NaN
# 1763   NaN
# 1769   NaN
# 1824   NaN
# 1834   NaN
# 1852   NaN
# 1911   NaN
# 1928   NaN
# 1939   NaN
# 1945   NaN
# 1961   NaN
# 2060   NaN
# 2092   NaN
# Name: OriginalCost, dtype: float64
# After OriginalCost
#  Series([], Name: OriginalCost, dtype: float64)
# Before DiscountedCost
#  Series([], Name: DiscountedCost, dtype: float64)
# After DiscountedCost
#  Series([], Name: DiscountedCost, dtype: float64)
# Before Controller
#  1782    NaN
# 1824    NaN
# 1870    NaN
# 2092    NaN
# 2114    NaN
# Name: Controller, dtype: object
# After Controller
#  Series([], Name: Controller, dtype: object)
# Before Achievements
#  Series([], Name: Achievements, dtype: float64)
# After Achievements
#  Series([], Name: Achievements, dtype: float64)
# Before Storage
#  5      NaN
# 21     NaN
# 27     NaN
# 33     NaN
# 39     NaN
#         ..
# 2119   NaN
# 2124   NaN
# 2126   NaN
# 2131   NaN
# 2156   NaN
# Name: Storage, Length: 396, dtype: float64
# After Storage
#  Series([], Name: Storage, dtype: float64)
# Before Platform-Mobile
#  Series([], Name: Platform-Mobile, dtype: bool)
# After Platform-Mobile
#  Series([], Name: Platform-Mobile, dtype: bool)
# Before Platform-PC
#  Series([], Name: Platform-PC, dtype: bool)
# After Platform-PC
#  Series([], Name: Platform-PC, dtype: bool)
# Before Platform-Xbox
#  Series([], Name: Platform-Xbox, dtype: bool)
# After Platform-Xbox
#  Series([], Name: Platform-Xbox, dtype: bool)
# Before Platform-PlayStation
#  Series([], Name: Platform-PlayStation, dtype: bool)
# After Platform-PlayStation
#  Series([], Name: Platform-PlayStation, dtype: bool)
# Before Platform-Nintendo
#  Series([], Name: Platform-Nintendo, dtype: bool)
# After Platform-Nintendo
#  Series([], Name: Platform-Nintendo, dtype: bool)
# Before Platform-Sega
#  Series([], Name: Platform-Sega, dtype: bool)
# After Platform-Sega
#  Series([], Name: Platform-Sega, dtype: bool)
# Before RatingsBreakdown-Recommended
#  17     NaN
# 22     NaN
# 23     NaN
# 32     NaN
# 56     NaN
#         ..
# 2101   NaN
# 2105   NaN
# 2106   NaN
# 2122   NaN
# 2124   NaN
# Name: RatingsBreakdown-Recommended, Length: 206, dtype: float64
# After RatingsBreakdown-Recommended
#  Series([], Name: RatingsBreakdown-Recommended, dtype: float64)
# Before RatingsBreakdown-Meh
#  23     NaN
# 32     NaN
# 56     NaN
# 81     NaN
# 94     NaN
#         ..
# 2122   NaN
# 2123   NaN
# 2134   NaN
# 2139   NaN
# 2147   NaN
# Name: RatingsBreakdown-Meh, Length: 143, dtype: float64
# After RatingsBreakdown-Meh
#  Series([], Name: RatingsBreakdown-Meh, dtype: float64)
# Before RatingsBreakdown-Exceptional
#  1      NaN
# 2      NaN
# 17     NaN
# 22     NaN
# 23     NaN
#         ..
# 2118   NaN
# 2123   NaN
# 2124   NaN
# 2144   NaN
# 2154   NaN
# Name: RatingsBreakdown-Exceptional, Length: 505, dtype: float64
# After RatingsBreakdown-Exceptional
#  Series([], Name: RatingsBreakdown-Exceptional, dtype: float64)
# Before RatingsBreakdown-Skip
#  11     NaN
# 15     NaN
# 17     NaN
# 22     NaN
# 23     NaN
#         ..
# 2122   NaN
# 2124   NaN
# 2127   NaN
# 2134   NaN
# 2139   NaN
# Name: RatingsBreakdown-Skip, Length: 311, dtype: float64
# After RatingsBreakdown-Skip
#  Series([], Name: RatingsBreakdown-Skip, dtype: float64)
# Before 1980s
#  Series([], Name: 1980s, dtype: bool)
# After 1980s
#  Series([], Name: 1980s, dtype: bool)
# Before 1990's
#  Series([], Name: 1990's, dtype: bool)
# After 1990's
#  Series([], Name: 1990's, dtype: bool)
# Before 2.5D
#  Series([], Name: 2.5D, dtype: bool)
# After 2.5D
#  Series([], Name: 2.5D, dtype: bool)
# Before 2D
#  Series([], Name: 2D, dtype: bool)
# After 2D
#  Series([], Name: 2D, dtype: bool)
# Before 2D Fighter
#  Series([], Name: 2D Fighter, dtype: bool)
# After 2D Fighter
#  Series([], Name: 2D Fighter, dtype: bool)
# Before 2D Platformer
#  Series([], Name: 2D Platformer, dtype: bool)
# After 2D Platformer
#  Series([], Name: 2D Platformer, dtype: bool)
# Before 3D
#  Series([], Name: 3D, dtype: bool)
# After 3D
#  Series([], Name: 3D, dtype: bool)
# Before 3D Fighter
#  Series([], Name: 3D Fighter, dtype: bool)
# After 3D Fighter
#  Series([], Name: 3D Fighter, dtype: bool)
# Before 3D Platformer
#  Series([], Name: 3D Platformer, dtype: bool)
# After 3D Platformer
#  Series([], Name: 3D Platformer, dtype: bool)
# Before 3D Vision
#  Series([], Name: 3D Vision, dtype: bool)
# After 3D Vision
#  Series([], Name: 3D Vision, dtype: bool)
# Before 4 Player Local
#  Series([], Name: 4 Player Local, dtype: bool)
# After 4 Player Local
#  Series([], Name: 4 Player Local, dtype: bool)
# Before 4X
#  Series([], Name: 4X, dtype: bool)
# After 4X
#  Series([], Name: 4X, dtype: bool)
# Before 6DOF
#  Series([], Name: 6DOF, dtype: bool)
# After 6DOF
#  Series([], Name: 6DOF, dtype: bool)
# Before Abstract
#  Series([], Name: Abstract, dtype: bool)
# After Abstract
#  Series([], Name: Abstract, dtype: bool)
# Before Action
#  Series([], Name: Action, dtype: bool)
# After Action
#  Series([], Name: Action, dtype: bool)
# Before Action RPG
#  Series([], Name: Action RPG, dtype: bool)
# After Action RPG
#  Series([], Name: Action RPG, dtype: bool)
# Before Action Roguelike
#  Series([], Name: Action Roguelike, dtype: bool)
# After Action Roguelike
#  Series([], Name: Action Roguelike, dtype: bool)
# Before Action-Adventure
#  Series([], Name: Action-Adventure, dtype: bool)
# After Action-Adventure
#  Series([], Name: Action-Adventure, dtype: bool)
# Before Addictive
#  Series([], Name: Addictive, dtype: bool)
# After Addictive
#  Series([], Name: Addictive, dtype: bool)
# Before Adventure
#  Series([], Name: Adventure, dtype: bool)
# After Adventure
#  Series([], Name: Adventure, dtype: bool)
# Before Agriculture
#  Series([], Name: Agriculture, dtype: bool)
# After Agriculture
#  Series([], Name: Agriculture, dtype: bool)
# Before Aliens
#  Series([], Name: Aliens, dtype: bool)
# After Aliens
#  Series([], Name: Aliens, dtype: bool)
# Before Alternate History
#  Series([], Name: Alternate History, dtype: bool)
# After Alternate History
#  Series([], Name: Alternate History, dtype: bool)
# Before Ambient
#  Series([], Name: Ambient, dtype: bool)
# After Ambient
#  Series([], Name: Ambient, dtype: bool)
# Before America
#  Series([], Name: America, dtype: bool)
# After America
#  Series([], Name: America, dtype: bool)
# Before Animation & Modeling
#  Series([], Name: Animation & Modeling, dtype: bool)
# After Animation & Modeling
#  Series([], Name: Animation & Modeling, dtype: bool)
# Before Anime
#  Series([], Name: Anime, dtype: bool)
# After Anime
#  Series([], Name: Anime, dtype: bool)
# Before Arcade
#  Series([], Name: Arcade, dtype: bool)
# After Arcade
#  Series([], Name: Arcade, dtype: bool)
# Before Archery
#  Series([], Name: Archery, dtype: bool)
# After Archery
#  Series([], Name: Archery, dtype: bool)
# Before Arena Shooter
#  Series([], Name: Arena Shooter, dtype: bool)
# After Arena Shooter
#  Series([], Name: Arena Shooter, dtype: bool)
# Before Artificial Intelligence
#  Series([], Name: Artificial Intelligence, dtype: bool)
# After Artificial Intelligence
#  Series([], Name: Artificial Intelligence, dtype: bool)
# Before Assassin
#  Series([], Name: Assassin, dtype: bool)
# After Assassin
#  Series([], Name: Assassin, dtype: bool)
# Before Asynchronous Multiplayer
#  Series([], Name: Asynchronous Multiplayer, dtype: bool)
# After Asynchronous Multiplayer
#  Series([], Name: Asynchronous Multiplayer, dtype: bool)
# Before Atmospheric
#  Series([], Name: Atmospheric, dtype: bool)
# After Atmospheric
#  Series([], Name: Atmospheric, dtype: bool)
# Before Audio Production
#  Series([], Name: Audio Production, dtype: bool)
# After Audio Production
#  Series([], Name: Audio Production, dtype: bool)
# Before Auto Battler
#  Series([], Name: Auto Battler, dtype: bool)
# After Auto Battler
#  Series([], Name: Auto Battler, dtype: bool)
# Before Automation
#  Series([], Name: Automation, dtype: bool)
# After Automation
#  Series([], Name: Automation, dtype: bool)
# Before Automobile Sim
#  Series([], Name: Automobile Sim, dtype: bool)
# After Automobile Sim
#  Series([], Name: Automobile Sim, dtype: bool)
# Before Base Building
#  Series([], Name: Base Building, dtype: bool)
# After Base Building
#  Series([], Name: Base Building, dtype: bool)
# Before Baseball
#  Series([], Name: Baseball, dtype: bool)
# After Baseball
#  Series([], Name: Baseball, dtype: bool)
# Before Based On A Novel
#  Series([], Name: Based On A Novel, dtype: bool)
# After Based On A Novel
#  Series([], Name: Based On A Novel, dtype: bool)
# Before Basketball
#  Series([], Name: Basketball, dtype: bool)
# After Basketball
#  Series([], Name: Basketball, dtype: bool)
# Before Batman
#  Series([], Name: Batman, dtype: bool)
# After Batman
#  Series([], Name: Batman, dtype: bool)
# Before Battle Royale
#  Series([], Name: Battle Royale, dtype: bool)
# After Battle Royale
#  Series([], Name: Battle Royale, dtype: bool)
# Before Beat 'em up
#  Series([], Name: Beat 'em up, dtype: bool)
# After Beat 'em up
#  Series([], Name: Beat 'em up, dtype: bool)
# Before Beautiful
#  Series([], Name: Beautiful, dtype: bool)
# After Beautiful
#  Series([], Name: Beautiful, dtype: bool)
# Before Benchmark
#  Series([], Name: Benchmark, dtype: bool)
# After Benchmark
#  Series([], Name: Benchmark, dtype: bool)
# Before Bikes
#  Series([], Name: Bikes, dtype: bool)
# After Bikes
#  Series([], Name: Bikes, dtype: bool)
# Before Blood
#  Series([], Name: Blood, dtype: bool)
# After Blood
#  Series([], Name: Blood, dtype: bool)
# Before Board Game
#  Series([], Name: Board Game, dtype: bool)
# After Board Game
#  Series([], Name: Board Game, dtype: bool)
# Before Bowling
#  Series([], Name: Bowling, dtype: bool)
# After Bowling
#  Series([], Name: Bowling, dtype: bool)
# Before Boxing
#  Series([], Name: Boxing, dtype: bool)
# After Boxing
#  Series([], Name: Boxing, dtype: bool)
# Before Building
#  Series([], Name: Building, dtype: bool)
# After Building
#  Series([], Name: Building, dtype: bool)
# Before Bullet Hell
#  Series([], Name: Bullet Hell, dtype: bool)
# After Bullet Hell
#  Series([], Name: Bullet Hell, dtype: bool)
# Before Bullet Time
#  Series([], Name: Bullet Time, dtype: bool)
# After Bullet Time
#  Series([], Name: Bullet Time, dtype: bool)
# Before CRPG
#  Series([], Name: CRPG, dtype: bool)
# After CRPG
#  Series([], Name: CRPG, dtype: bool)
# Before Capitalism
#  Series([], Name: Capitalism, dtype: bool)
# After Capitalism
#  Series([], Name: Capitalism, dtype: bool)
# Before Card Battler
#  Series([], Name: Card Battler, dtype: bool)
# After Card Battler
#  Series([], Name: Card Battler, dtype: bool)
# Before Card Game
#  Series([], Name: Card Game, dtype: bool)
# After Card Game
#  Series([], Name: Card Game, dtype: bool)
# Before Cartoon
#  Series([], Name: Cartoon, dtype: bool)
# After Cartoon
#  Series([], Name: Cartoon, dtype: bool)
# Before Cartoony
#  Series([], Name: Cartoony, dtype: bool)
# After Cartoony
#  Series([], Name: Cartoony, dtype: bool)
# Before Casual
#  Series([], Name: Casual, dtype: bool)
# After Casual
#  Series([], Name: Casual, dtype: bool)
# Before Cats
#  Series([], Name: Cats, dtype: bool)
# After Cats
#  Series([], Name: Cats, dtype: bool)
# Before Character Action Game
#  Series([], Name: Character Action Game, dtype: bool)
# After Character Action Game
#  Series([], Name: Character Action Game, dtype: bool)
# Before Character Customization
#  Series([], Name: Character Customization, dtype: bool)
# After Character Customization
#  Series([], Name: Character Customization, dtype: bool)
# Before Chess
#  Series([], Name: Chess, dtype: bool)
# After Chess
#  Series([], Name: Chess, dtype: bool)
# Before Choices Matter
#  Series([], Name: Choices Matter, dtype: bool)
# After Choices Matter
#  Series([], Name: Choices Matter, dtype: bool)
# Before Choose Your Own Adventure
#  Series([], Name: Choose Your Own Adventure, dtype: bool)
# After Choose Your Own Adventure
#  Series([], Name: Choose Your Own Adventure, dtype: bool)
# Before Cinematic
#  Series([], Name: Cinematic, dtype: bool)
# After Cinematic
#  Series([], Name: Cinematic, dtype: bool)
# Before City Builder
#  Series([], Name: City Builder, dtype: bool)
# After City Builder
#  Series([], Name: City Builder, dtype: bool)
# Before Class-Based
#  Series([], Name: Class-Based, dtype: bool)
# After Class-Based
#  Series([], Name: Class-Based, dtype: bool)
# Before Classic
#  Series([], Name: Classic, dtype: bool)
# After Classic
#  Series([], Name: Classic, dtype: bool)
# Before Clicker
#  Series([], Name: Clicker, dtype: bool)
# After Clicker
#  Series([], Name: Clicker, dtype: bool)
# Before Co-op
#  Series([], Name: Co-op, dtype: bool)
# After Co-op
#  Series([], Name: Co-op, dtype: bool)
# Before Co-op Campaign
#  Series([], Name: Co-op Campaign, dtype: bool)
# After Co-op Campaign
#  Series([], Name: Co-op Campaign, dtype: bool)
# Before Cold War
#  Series([], Name: Cold War, dtype: bool)
# After Cold War
#  Series([], Name: Cold War, dtype: bool)
# Before Collectathon
#  Series([], Name: Collectathon, dtype: bool)
# After Collectathon
#  Series([], Name: Collectathon, dtype: bool)
# Before Colony Sim
#  Series([], Name: Colony Sim, dtype: bool)
# After Colony Sim
#  Series([], Name: Colony Sim, dtype: bool)
# Before Colorful
#  Series([], Name: Colorful, dtype: bool)
# After Colorful
#  Series([], Name: Colorful, dtype: bool)
# Before Combat
#  Series([], Name: Combat, dtype: bool)
# After Combat
#  Series([], Name: Combat, dtype: bool)
# Before Combat Racing
#  Series([], Name: Combat Racing, dtype: bool)
# After Combat Racing
#  Series([], Name: Combat Racing, dtype: bool)
# Before Comedy
#  Series([], Name: Comedy, dtype: bool)
# After Comedy
#  Series([], Name: Comedy, dtype: bool)
# Before Comic Book
#  Series([], Name: Comic Book, dtype: bool)
# After Comic Book
#  Series([], Name: Comic Book, dtype: bool)
# Before Competitive
#  Series([], Name: Competitive, dtype: bool)
# After Competitive
#  Series([], Name: Competitive, dtype: bool)
# Before Conspiracy
#  Series([], Name: Conspiracy, dtype: bool)
# After Conspiracy
#  Series([], Name: Conspiracy, dtype: bool)
# Before Conversation
#  Series([], Name: Conversation, dtype: bool)
# After Conversation
#  Series([], Name: Conversation, dtype: bool)
# Before Crafting
#  Series([], Name: Crafting, dtype: bool)
# After Crafting
#  Series([], Name: Crafting, dtype: bool)
# Before Crime
#  Series([], Name: Crime, dtype: bool)
# After Crime
#  Series([], Name: Crime, dtype: bool)
# Before Crowdfunded
#  Series([], Name: Crowdfunded, dtype: bool)
# After Crowdfunded
#  Series([], Name: Crowdfunded, dtype: bool)
# Before Cult Classic
#  Series([], Name: Cult Classic, dtype: bool)
# After Cult Classic
#  Series([], Name: Cult Classic, dtype: bool)
# Before Cute
#  Series([], Name: Cute, dtype: bool)
# After Cute
#  Series([], Name: Cute, dtype: bool)
# Before Cyberpunk
#  Series([], Name: Cyberpunk, dtype: bool)
# After Cyberpunk
#  Series([], Name: Cyberpunk, dtype: bool)
# Before Cycling
#  Series([], Name: Cycling, dtype: bool)
# After Cycling
#  Series([], Name: Cycling, dtype: bool)
# Before Dark
#  Series([], Name: Dark, dtype: bool)
# After Dark
#  Series([], Name: Dark, dtype: bool)
# Before Dark Comedy
#  Series([], Name: Dark Comedy, dtype: bool)
# After Dark Comedy
#  Series([], Name: Dark Comedy, dtype: bool)
# Before Dark Fantasy
#  Series([], Name: Dark Fantasy, dtype: bool)
# After Dark Fantasy
#  Series([], Name: Dark Fantasy, dtype: bool)
# Before Dark Humor
#  Series([], Name: Dark Humor, dtype: bool)
# After Dark Humor
#  Series([], Name: Dark Humor, dtype: bool)
# Before Dating Sim
#  Series([], Name: Dating Sim, dtype: bool)
# After Dating Sim
#  Series([], Name: Dating Sim, dtype: bool)
# Before Deckbuilding
#  Series([], Name: Deckbuilding, dtype: bool)
# After Deckbuilding
#  Series([], Name: Deckbuilding, dtype: bool)
# Before Demons
#  Series([], Name: Demons, dtype: bool)
# After Demons
#  Series([], Name: Demons, dtype: bool)
# Before Design & Illustration
#  Series([], Name: Design & Illustration, dtype: bool)
# After Design & Illustration
#  Series([], Name: Design & Illustration, dtype: bool)
# Before Destruction
#  Series([], Name: Destruction, dtype: bool)
# After Destruction
#  Series([], Name: Destruction, dtype: bool)
# Before Detective
#  Series([], Name: Detective, dtype: bool)
# After Detective
#  Series([], Name: Detective, dtype: bool)
# Before Difficult
#  Series([], Name: Difficult, dtype: bool)
# After Difficult
#  Series([], Name: Difficult, dtype: bool)
# Before Dinosaurs
#  Series([], Name: Dinosaurs, dtype: bool)
# After Dinosaurs
#  Series([], Name: Dinosaurs, dtype: bool)
# Before Diplomacy
#  Series([], Name: Diplomacy, dtype: bool)
# After Diplomacy
#  Series([], Name: Diplomacy, dtype: bool)
# Before Documentary
#  Series([], Name: Documentary, dtype: bool)
# After Documentary
#  Series([], Name: Documentary, dtype: bool)
# Before Dog
#  Series([], Name: Dog, dtype: bool)
# After Dog
#  Series([], Name: Dog, dtype: bool)
# Before Dragons
#  Series([], Name: Dragons, dtype: bool)
# After Dragons
#  Series([], Name: Dragons, dtype: bool)
# Before Drama
#  Series([], Name: Drama, dtype: bool)
# After Drama
#  Series([], Name: Drama, dtype: bool)
# Before Driving
#  Series([], Name: Driving, dtype: bool)
# After Driving
#  Series([], Name: Driving, dtype: bool)
# Before Dungeon Crawler
#  Series([], Name: Dungeon Crawler, dtype: bool)
# After Dungeon Crawler
#  Series([], Name: Dungeon Crawler, dtype: bool)
# Before Dungeons & Dragons
#  Series([], Name: Dungeons & Dragons, dtype: bool)
# After Dungeons & Dragons
#  Series([], Name: Dungeons & Dragons, dtype: bool)
# Before Dynamic Narration
#  Series([], Name: Dynamic Narration, dtype: bool)
# After Dynamic Narration
#  Series([], Name: Dynamic Narration, dtype: bool)
# Before Dystopian
#  Series([], Name: Dystopian, dtype: bool)
# After Dystopian
#  Series([], Name: Dystopian, dtype: bool)
# Before Early Access
#  Series([], Name: Early Access, dtype: bool)
# After Early Access
#  Series([], Name: Early Access, dtype: bool)
# Before Economy
#  Series([], Name: Economy, dtype: bool)
# After Economy
#  Series([], Name: Economy, dtype: bool)
# Before Education
#  Series([], Name: Education, dtype: bool)
# After Education
#  Series([], Name: Education, dtype: bool)
# Before Emotional
#  Series([], Name: Emotional, dtype: bool)
# After Emotional
#  Series([], Name: Emotional, dtype: bool)
# Before Epic
#  Series([], Name: Epic, dtype: bool)
# After Epic
#  Series([], Name: Epic, dtype: bool)
# Before Episodic
#  Series([], Name: Episodic, dtype: bool)
# After Episodic
#  Series([], Name: Episodic, dtype: bool)
# Before Experience
#  Series([], Name: Experience, dtype: bool)
# After Experience
#  Series([], Name: Experience, dtype: bool)
# Before Experimental
#  Series([], Name: Experimental, dtype: bool)
# After Experimental
#  Series([], Name: Experimental, dtype: bool)
# Before Exploration
#  Series([], Name: Exploration, dtype: bool)
# After Exploration
#  Series([], Name: Exploration, dtype: bool)
# Before FMV
#  Series([], Name: FMV, dtype: bool)
# After FMV
#  Series([], Name: FMV, dtype: bool)
# Before FPS
#  Series([], Name: FPS, dtype: bool)
# After FPS
#  Series([], Name: FPS, dtype: bool)
# Before Faith
#  Series([], Name: Faith, dtype: bool)
# After Faith
#  Series([], Name: Faith, dtype: bool)
# Before Family Friendly
#  Series([], Name: Family Friendly, dtype: bool)
# After Family Friendly
#  Series([], Name: Family Friendly, dtype: bool)
# Before Fantasy
#  Series([], Name: Fantasy, dtype: bool)
# After Fantasy
#  Series([], Name: Fantasy, dtype: bool)
# Before Farming Sim
#  Series([], Name: Farming Sim, dtype: bool)
# After Farming Sim
#  Series([], Name: Farming Sim, dtype: bool)
# Before Fast-Paced
#  Series([], Name: Fast-Paced, dtype: bool)
# After Fast-Paced
#  Series([], Name: Fast-Paced, dtype: bool)
# Before Feature Film
#  Series([], Name: Feature Film, dtype: bool)
# After Feature Film
#  Series([], Name: Feature Film, dtype: bool)
# Before Female Protagonist
#  Series([], Name: Female Protagonist, dtype: bool)
# After Female Protagonist
#  Series([], Name: Female Protagonist, dtype: bool)
# Before Fighting
#  Series([], Name: Fighting, dtype: bool)
# After Fighting
#  Series([], Name: Fighting, dtype: bool)
# Before First-Person
#  Series([], Name: First-Person, dtype: bool)
# After First-Person
#  Series([], Name: First-Person, dtype: bool)
# Before Fishing
#  Series([], Name: Fishing, dtype: bool)
# After Fishing
#  Series([], Name: Fishing, dtype: bool)
# Before Flight
#  Series([], Name: Flight, dtype: bool)
# After Flight
#  Series([], Name: Flight, dtype: bool)
# Before Football
#  Series([], Name: Football, dtype: bool)
# After Football
#  Series([], Name: Football, dtype: bool)
# Before Free to Play
#  Series([], Name: Free to Play, dtype: bool)
# After Free to Play
#  Series([], Name: Free to Play, dtype: bool)
# Before Funny
#  Series([], Name: Funny, dtype: bool)
# After Funny
#  Series([], Name: Funny, dtype: bool)
# Before Futuristic
#  Series([], Name: Futuristic, dtype: bool)
# After Futuristic
#  Series([], Name: Futuristic, dtype: bool)
# Before Gambling
#  Series([], Name: Gambling, dtype: bool)
# After Gambling
#  Series([], Name: Gambling, dtype: bool)
# Before Game Development
#  Series([], Name: Game Development, dtype: bool)
# After Game Development
#  Series([], Name: Game Development, dtype: bool)
# Before GameMaker
#  Series([], Name: GameMaker, dtype: bool)
# After GameMaker
#  Series([], Name: GameMaker, dtype: bool)
# Before Games Workshop
#  Series([], Name: Games Workshop, dtype: bool)
# After Games Workshop
#  Series([], Name: Games Workshop, dtype: bool)
# Before Gaming
#  Series([], Name: Gaming, dtype: bool)
# After Gaming
#  Series([], Name: Gaming, dtype: bool)
# Before God Game
#  Series([], Name: God Game, dtype: bool)
# After God Game
#  Series([], Name: God Game, dtype: bool)
# Before Golf
#  Series([], Name: Golf, dtype: bool)
# After Golf
#  Series([], Name: Golf, dtype: bool)
# Before Gore
#  Series([], Name: Gore, dtype: bool)
# After Gore
#  Series([], Name: Gore, dtype: bool)
# Before Gothic
#  Series([], Name: Gothic, dtype: bool)
# After Gothic
#  Series([], Name: Gothic, dtype: bool)
# Before Grand Strategy
#  Series([], Name: Grand Strategy, dtype: bool)
# After Grand Strategy
#  Series([], Name: Grand Strategy, dtype: bool)
# Before Great Soundtrack
#  Series([], Name: Great Soundtrack, dtype: bool)
# After Great Soundtrack
#  Series([], Name: Great Soundtrack, dtype: bool)
# Before Grid-Based Movement
#  Series([], Name: Grid-Based Movement, dtype: bool)
# After Grid-Based Movement
#  Series([], Name: Grid-Based Movement, dtype: bool)
# Before Gun Customization
#  Series([], Name: Gun Customization, dtype: bool)
# After Gun Customization
#  Series([], Name: Gun Customization, dtype: bool)
# Before Hack and Slash
#  Series([], Name: Hack and Slash, dtype: bool)
# After Hack and Slash
#  Series([], Name: Hack and Slash, dtype: bool)
# Before Hacking
#  Series([], Name: Hacking, dtype: bool)
# After Hacking
#  Series([], Name: Hacking, dtype: bool)
# Before Hand-drawn
#  Series([], Name: Hand-drawn, dtype: bool)
# After Hand-drawn
#  Series([], Name: Hand-drawn, dtype: bool)
# Before Heist
#  Series([], Name: Heist, dtype: bool)
# After Heist
#  Series([], Name: Heist, dtype: bool)
# Before Hentai
#  Series([], Name: Hentai, dtype: bool)
# After Hentai
#  Series([], Name: Hentai, dtype: bool)
# Before Hero Shooter
#  Series([], Name: Hero Shooter, dtype: bool)
# After Hero Shooter
#  Series([], Name: Hero Shooter, dtype: bool)
# Before Hex Grid
#  Series([], Name: Hex Grid, dtype: bool)
# After Hex Grid
#  Series([], Name: Hex Grid, dtype: bool)
# Before Hidden Object
#  Series([], Name: Hidden Object, dtype: bool)
# After Hidden Object
#  Series([], Name: Hidden Object, dtype: bool)
# Before Historical
#  Series([], Name: Historical, dtype: bool)
# After Historical
#  Series([], Name: Historical, dtype: bool)
# Before Horror
#  Series([], Name: Horror, dtype: bool)
# After Horror
#  Series([], Name: Horror, dtype: bool)
# Before Horses
#  Series([], Name: Horses, dtype: bool)
# After Horses
#  Series([], Name: Horses, dtype: bool)
# Before Hunting
#  Series([], Name: Hunting, dtype: bool)
# After Hunting
#  Series([], Name: Hunting, dtype: bool)
# Before Illuminati
#  Series([], Name: Illuminati, dtype: bool)
# After Illuminati
#  Series([], Name: Illuminati, dtype: bool)
# Before Immersive
#  Series([], Name: Immersive, dtype: bool)
# After Immersive
#  Series([], Name: Immersive, dtype: bool)
# Before Immersive Sim
#  Series([], Name: Immersive Sim, dtype: bool)
# After Immersive Sim
#  Series([], Name: Immersive Sim, dtype: bool)
# Before Intentionally Awkward Controls
#  Series([], Name: Intentionally Awkward Controls, dtype: bool)
# After Intentionally Awkward Controls
#  Series([], Name: Intentionally Awkward Controls, dtype: bool)
# Before Interactive Fiction
#  Series([], Name: Interactive Fiction, dtype: bool)
# After Interactive Fiction
#  Series([], Name: Interactive Fiction, dtype: bool)
# Before Inventory Management
#  Series([], Name: Inventory Management, dtype: bool)
# After Inventory Management
#  Series([], Name: Inventory Management, dtype: bool)
# Before Investigation
#  Series([], Name: Investigation, dtype: bool)
# After Investigation
#  Series([], Name: Investigation, dtype: bool)
# Before Isometric
#  Series([], Name: Isometric, dtype: bool)
# After Isometric
#  Series([], Name: Isometric, dtype: bool)
# Before JRPG
#  Series([], Name: JRPG, dtype: bool)
# After JRPG
#  Series([], Name: JRPG, dtype: bool)
# Before Jet
#  Series([], Name: Jet, dtype: bool)
# After Jet
#  Series([], Name: Jet, dtype: bool)
# Before Kickstarter
#  Series([], Name: Kickstarter, dtype: bool)
# After Kickstarter
#  Series([], Name: Kickstarter, dtype: bool)
# Before LEGO
#  Series([], Name: LEGO, dtype: bool)
# After LEGO
#  Series([], Name: LEGO, dtype: bool)
# Before LGBTQ+
#  Series([], Name: LGBTQ+, dtype: bool)
# After LGBTQ+
#  Series([], Name: LGBTQ+, dtype: bool)
# Before Lara Croft
#  Series([], Name: Lara Croft, dtype: bool)
# After Lara Croft
#  Series([], Name: Lara Croft, dtype: bool)
# Before Lemmings
#  Series([], Name: Lemmings, dtype: bool)
# After Lemmings
#  Series([], Name: Lemmings, dtype: bool)
# Before Level Editor
#  Series([], Name: Level Editor, dtype: bool)
# After Level Editor
#  Series([], Name: Level Editor, dtype: bool)
# Before Life Sim
#  Series([], Name: Life Sim, dtype: bool)
# After Life Sim
#  Series([], Name: Life Sim, dtype: bool)
# Before Linear
#  Series([], Name: Linear, dtype: bool)
# After Linear
#  Series([], Name: Linear, dtype: bool)
# Before Local Co-Op
#  Series([], Name: Local Co-Op, dtype: bool)
# After Local Co-Op
#  Series([], Name: Local Co-Op, dtype: bool)
# Before Local Multiplayer
#  Series([], Name: Local Multiplayer, dtype: bool)
# After Local Multiplayer
#  Series([], Name: Local Multiplayer, dtype: bool)
# Before Logic
#  Series([], Name: Logic, dtype: bool)
# After Logic
#  Series([], Name: Logic, dtype: bool)
# Before Loot
#  Series([], Name: Loot, dtype: bool)
# After Loot
#  Series([], Name: Loot, dtype: bool)
# Before Looter Shooter
#  Series([], Name: Looter Shooter, dtype: bool)
# After Looter Shooter
#  Series([], Name: Looter Shooter, dtype: bool)
# Before Lore-Rich
#  Series([], Name: Lore-Rich, dtype: bool)
# After Lore-Rich
#  Series([], Name: Lore-Rich, dtype: bool)
# Before Lovecraftian
#  Series([], Name: Lovecraftian, dtype: bool)
# After Lovecraftian
#  Series([], Name: Lovecraftian, dtype: bool)
# Before MMORPG
#  Series([], Name: MMORPG, dtype: bool)
# After MMORPG
#  Series([], Name: MMORPG, dtype: bool)
# Before MOBA
#  Series([], Name: MOBA, dtype: bool)
# After MOBA
#  Series([], Name: MOBA, dtype: bool)
# Before Magic
#  Series([], Name: Magic, dtype: bool)
# After Magic
#  Series([], Name: Magic, dtype: bool)
# Before Management
#  Series([], Name: Management, dtype: bool)
# After Management
#  Series([], Name: Management, dtype: bool)
# Before Mars
#  Series([], Name: Mars, dtype: bool)
# After Mars
#  Series([], Name: Mars, dtype: bool)
# Before Martial Arts
#  Series([], Name: Martial Arts, dtype: bool)
# After Martial Arts
#  Series([], Name: Martial Arts, dtype: bool)
# Before Massively Multiplayer
#  Series([], Name: Massively Multiplayer, dtype: bool)
# After Massively Multiplayer
#  Series([], Name: Massively Multiplayer, dtype: bool)
# Before Masterpiece
#  Series([], Name: Masterpiece, dtype: bool)
# After Masterpiece
#  Series([], Name: Masterpiece, dtype: bool)
# Before Match 3
#  Series([], Name: Match 3, dtype: bool)
# After Match 3
#  Series([], Name: Match 3, dtype: bool)
# Before Mature
#  Series([], Name: Mature, dtype: bool)
# After Mature
#  Series([], Name: Mature, dtype: bool)
# Before Mechs
#  Series([], Name: Mechs, dtype: bool)
# After Mechs
#  Series([], Name: Mechs, dtype: bool)
# Before Medical Sim
#  Series([], Name: Medical Sim, dtype: bool)
# After Medical Sim
#  Series([], Name: Medical Sim, dtype: bool)
# Before Medieval
#  Series([], Name: Medieval, dtype: bool)
# After Medieval
#  Series([], Name: Medieval, dtype: bool)
# Before Memes
#  Series([], Name: Memes, dtype: bool)
# After Memes
#  Series([], Name: Memes, dtype: bool)
# Before Metroidvania
#  Series([], Name: Metroidvania, dtype: bool)
# After Metroidvania
#  Series([], Name: Metroidvania, dtype: bool)
# Before Military
#  Series([], Name: Military, dtype: bool)
# After Military
#  Series([], Name: Military, dtype: bool)
# Before Mini Golf
#  Series([], Name: Mini Golf, dtype: bool)
# After Mini Golf
#  Series([], Name: Mini Golf, dtype: bool)
# Before Minigames
#  Series([], Name: Minigames, dtype: bool)
# After Minigames
#  Series([], Name: Minigames, dtype: bool)
# Before Minimalist
#  Series([], Name: Minimalist, dtype: bool)
# After Minimalist
#  Series([], Name: Minimalist, dtype: bool)
# Before Mining
#  Series([], Name: Mining, dtype: bool)
# After Mining
#  Series([], Name: Mining, dtype: bool)
# Before Mod
#  Series([], Name: Mod, dtype: bool)
# After Mod
#  Series([], Name: Mod, dtype: bool)
# Before Moddable
#  Series([], Name: Moddable, dtype: bool)
# After Moddable
#  Series([], Name: Moddable, dtype: bool)
# Before Modern
#  Series([], Name: Modern, dtype: bool)
# After Modern
#  Series([], Name: Modern, dtype: bool)
# Before Motocross
#  Series([], Name: Motocross, dtype: bool)
# After Motocross
#  Series([], Name: Motocross, dtype: bool)
# Before Motorbike
#  Series([], Name: Motorbike, dtype: bool)
# After Motorbike
#  Series([], Name: Motorbike, dtype: bool)
# Before Mouse only
#  Series([], Name: Mouse only, dtype: bool)
# After Mouse only
#  Series([], Name: Mouse only, dtype: bool)
# Before Movie
#  Series([], Name: Movie, dtype: bool)
# After Movie
#  Series([], Name: Movie, dtype: bool)
# Before Multiplayer
#  Series([], Name: Multiplayer, dtype: bool)
# After Multiplayer
#  Series([], Name: Multiplayer, dtype: bool)
# Before Multiple Endings
#  Series([], Name: Multiple Endings, dtype: bool)
# After Multiple Endings
#  Series([], Name: Multiple Endings, dtype: bool)
# Before Music
#  Series([], Name: Music, dtype: bool)
# After Music
#  Series([], Name: Music, dtype: bool)
# Before Music-Based Procedural Generation
#  Series([], Name: Music-Based Procedural Generation, dtype: bool)
# After Music-Based Procedural Generation
#  Series([], Name: Music-Based Procedural Generation, dtype: bool)
# Before Mystery
#  Series([], Name: Mystery, dtype: bool)
# After Mystery
#  Series([], Name: Mystery, dtype: bool)
# Before Mystery Dungeon
#  Series([], Name: Mystery Dungeon, dtype: bool)
# After Mystery Dungeon
#  Series([], Name: Mystery Dungeon, dtype: bool)
# Before Mythology
#  Series([], Name: Mythology, dtype: bool)
# After Mythology
#  Series([], Name: Mythology, dtype: bool)
# Before NSFW
#  Series([], Name: NSFW, dtype: bool)
# After NSFW
#  Series([], Name: NSFW, dtype: bool)
# Before Narration
#  Series([], Name: Narration, dtype: bool)
# After Narration
#  Series([], Name: Narration, dtype: bool)
# Before Narrative
#  Series([], Name: Narrative, dtype: bool)
# After Narrative
#  Series([], Name: Narrative, dtype: bool)
# Before Nature
#  Series([], Name: Nature, dtype: bool)
# After Nature
#  Series([], Name: Nature, dtype: bool)
# Before Naval
#  Series([], Name: Naval, dtype: bool)
# After Naval
#  Series([], Name: Naval, dtype: bool)
# Before Naval Combat
#  Series([], Name: Naval Combat, dtype: bool)
# After Naval Combat
#  Series([], Name: Naval Combat, dtype: bool)
# Before Ninja
#  Series([], Name: Ninja, dtype: bool)
# After Ninja
#  Series([], Name: Ninja, dtype: bool)
# Before Noir
#  Series([], Name: Noir, dtype: bool)
# After Noir
#  Series([], Name: Noir, dtype: bool)
# Before Nonlinear
#  Series([], Name: Nonlinear, dtype: bool)
# After Nonlinear
#  Series([], Name: Nonlinear, dtype: bool)
# Before Nostalgia
#  Series([], Name: Nostalgia, dtype: bool)
# After Nostalgia
#  Series([], Name: Nostalgia, dtype: bool)
# Before Nudity
#  Series([], Name: Nudity, dtype: bool)
# After Nudity
#  Series([], Name: Nudity, dtype: bool)
# Before Offroad
#  Series([], Name: Offroad, dtype: bool)
# After Offroad
#  Series([], Name: Offroad, dtype: bool)
# Before Old School
#  Series([], Name: Old School, dtype: bool)
# After Old School
#  Series([], Name: Old School, dtype: bool)
# Before On-Rails Shooter
#  Series([], Name: On-Rails Shooter, dtype: bool)
# After On-Rails Shooter
#  Series([], Name: On-Rails Shooter, dtype: bool)
# Before Online Co-Op
#  Series([], Name: Online Co-Op, dtype: bool)
# After Online Co-Op
#  Series([], Name: Online Co-Op, dtype: bool)
# Before Open World
#  Series([], Name: Open World, dtype: bool)
# After Open World
#  Series([], Name: Open World, dtype: bool)
# Before Open World Survival Craft
#  Series([], Name: Open World Survival Craft, dtype: bool)
# After Open World Survival Craft
#  Series([], Name: Open World Survival Craft, dtype: bool)
# Before Otome
#  Series([], Name: Otome, dtype: bool)
# After Otome
#  Series([], Name: Otome, dtype: bool)
# Before Outbreak Sim
#  Series([], Name: Outbreak Sim, dtype: bool)
# After Outbreak Sim
#  Series([], Name: Outbreak Sim, dtype: bool)
# Before Parkour
#  Series([], Name: Parkour, dtype: bool)
# After Parkour
#  Series([], Name: Parkour, dtype: bool)
# Before Parody
#  Series([], Name: Parody, dtype: bool)
# After Parody
#  Series([], Name: Parody, dtype: bool)
# Before Party
#  Series([], Name: Party, dtype: bool)
# After Party
#  Series([], Name: Party, dtype: bool)
# Before Party Game
#  Series([], Name: Party Game, dtype: bool)
# After Party Game
#  Series([], Name: Party Game, dtype: bool)
# Before Party-Based RPG
#  Series([], Name: Party-Based RPG, dtype: bool)
# After Party-Based RPG
#  Series([], Name: Party-Based RPG, dtype: bool)
# Before Perma Death
#  Series([], Name: Perma Death, dtype: bool)
# After Perma Death
#  Series([], Name: Perma Death, dtype: bool)
# Before Philosophical
#  Series([], Name: Philosophical, dtype: bool)
# After Philosophical
#  Series([], Name: Philosophical, dtype: bool)
# Before Photo Editing
#  Series([], Name: Photo Editing, dtype: bool)
# After Photo Editing
#  Series([], Name: Photo Editing, dtype: bool)
# Before Physics
#  Series([], Name: Physics, dtype: bool)
# After Physics
#  Series([], Name: Physics, dtype: bool)
# Before Pinball
#  Series([], Name: Pinball, dtype: bool)
# After Pinball
#  Series([], Name: Pinball, dtype: bool)
# Before Pirates
#  Series([], Name: Pirates, dtype: bool)
# After Pirates
#  Series([], Name: Pirates, dtype: bool)
# Before Pixel Graphics
#  Series([], Name: Pixel Graphics, dtype: bool)
# After Pixel Graphics
#  Series([], Name: Pixel Graphics, dtype: bool)
# Before Platformer
#  Series([], Name: Platformer, dtype: bool)
# After Platformer
#  Series([], Name: Platformer, dtype: bool)
# Before Point & Click
#  Series([], Name: Point & Click, dtype: bool)
# After Point & Click
#  Series([], Name: Point & Click, dtype: bool)
# Before Political
#  Series([], Name: Political, dtype: bool)
# After Political
#  Series([], Name: Political, dtype: bool)
# Before Political Sim
#  Series([], Name: Political Sim, dtype: bool)
# After Political Sim
#  Series([], Name: Political Sim, dtype: bool)
# Before Politics
#  Series([], Name: Politics, dtype: bool)
# After Politics
#  Series([], Name: Politics, dtype: bool)
# Before Pool
#  Series([], Name: Pool, dtype: bool)
# After Pool
#  Series([], Name: Pool, dtype: bool)
# Before Post-apocalyptic
#  Series([], Name: Post-apocalyptic, dtype: bool)
# After Post-apocalyptic
#  Series([], Name: Post-apocalyptic, dtype: bool)
# Before Precision Platformer
#  Series([], Name: Precision Platformer, dtype: bool)
# After Precision Platformer
#  Series([], Name: Precision Platformer, dtype: bool)
# Before Procedural Generation
#  Series([], Name: Procedural Generation, dtype: bool)
# After Procedural Generation
#  Series([], Name: Procedural Generation, dtype: bool)
# Before Programming
#  Series([], Name: Programming, dtype: bool)
# After Programming
#  Series([], Name: Programming, dtype: bool)
# Before Psychedelic
#  Series([], Name: Psychedelic, dtype: bool)
# After Psychedelic
#  Series([], Name: Psychedelic, dtype: bool)
# Before Psychological
#  Series([], Name: Psychological, dtype: bool)
# After Psychological
#  Series([], Name: Psychological, dtype: bool)
# Before Psychological Horror
#  Series([], Name: Psychological Horror, dtype: bool)
# After Psychological Horror
#  Series([], Name: Psychological Horror, dtype: bool)
# Before Puzzle
#  Series([], Name: Puzzle, dtype: bool)
# After Puzzle
#  Series([], Name: Puzzle, dtype: bool)
# Before Puzzle Platformer
#  Series([], Name: Puzzle Platformer, dtype: bool)
# After Puzzle Platformer
#  Series([], Name: Puzzle Platformer, dtype: bool)
# Before PvE
#  Series([], Name: PvE, dtype: bool)
# After PvE
#  Series([], Name: PvE, dtype: bool)
# Before PvP
#  Series([], Name: PvP, dtype: bool)
# After PvP
#  Series([], Name: PvP, dtype: bool)
# Before Quick-Time Events
#  Series([], Name: Quick-Time Events, dtype: bool)
# After Quick-Time Events
#  Series([], Name: Quick-Time Events, dtype: bool)
# Before RPG
#  Series([], Name: RPG, dtype: bool)
# After RPG
#  Series([], Name: RPG, dtype: bool)
# Before RPGMaker
#  Series([], Name: RPGMaker, dtype: bool)
# After RPGMaker
#  Series([], Name: RPGMaker, dtype: bool)
# Before RTS
#  Series([], Name: RTS, dtype: bool)
# After RTS
#  Series([], Name: RTS, dtype: bool)
# Before Racing
#  Series([], Name: Racing, dtype: bool)
# After Racing
#  Series([], Name: Racing, dtype: bool)
# Before Real Time Tactics
#  Series([], Name: Real Time Tactics, dtype: bool)
# After Real Time Tactics
#  Series([], Name: Real Time Tactics, dtype: bool)
# Before Real-Time
#  Series([], Name: Real-Time, dtype: bool)
# After Real-Time
#  Series([], Name: Real-Time, dtype: bool)
# Before Real-Time with Pause
#  Series([], Name: Real-Time with Pause, dtype: bool)
# After Real-Time with Pause
#  Series([], Name: Real-Time with Pause, dtype: bool)
# Before Realistic
#  Series([], Name: Realistic, dtype: bool)
# After Realistic
#  Series([], Name: Realistic, dtype: bool)
# Before Reboot
#  Series([], Name: Reboot, dtype: bool)
# After Reboot
#  Series([], Name: Reboot, dtype: bool)
# Before Relaxing
#  Series([], Name: Relaxing, dtype: bool)
# After Relaxing
#  Series([], Name: Relaxing, dtype: bool)
# Before Remake
#  Series([], Name: Remake, dtype: bool)
# After Remake
#  Series([], Name: Remake, dtype: bool)
# Before Replay Value
#  Series([], Name: Replay Value, dtype: bool)
# After Replay Value
#  Series([], Name: Replay Value, dtype: bool)
# Before Resource Management
#  Series([], Name: Resource Management, dtype: bool)
# After Resource Management
#  Series([], Name: Resource Management, dtype: bool)
# Before Retro
#  Series([], Name: Retro, dtype: bool)
# After Retro
#  Series([], Name: Retro, dtype: bool)
# Before Rhythm
#  Series([], Name: Rhythm, dtype: bool)
# After Rhythm
#  Series([], Name: Rhythm, dtype: bool)
# Before Robots
#  Series([], Name: Robots, dtype: bool)
# After Robots
#  Series([], Name: Robots, dtype: bool)
# Before Roguelike
#  Series([], Name: Roguelike, dtype: bool)
# After Roguelike
#  Series([], Name: Roguelike, dtype: bool)
# Before Roguelike Deckbuilder
#  Series([], Name: Roguelike Deckbuilder, dtype: bool)
# After Roguelike Deckbuilder
#  Series([], Name: Roguelike Deckbuilder, dtype: bool)
# Before Roguelite
#  Series([], Name: Roguelite, dtype: bool)
# After Roguelite
#  Series([], Name: Roguelite, dtype: bool)
# Before Roguevania
#  Series([], Name: Roguevania, dtype: bool)
# After Roguevania
#  Series([], Name: Roguevania, dtype: bool)
# Before Romance
#  Series([], Name: Romance, dtype: bool)
# After Romance
#  Series([], Name: Romance, dtype: bool)
# Before Rome
#  Series([], Name: Rome, dtype: bool)
# After Rome
#  Series([], Name: Rome, dtype: bool)
# Before Runner
#  Series([], Name: Runner, dtype: bool)
# After Runner
#  Series([], Name: Runner, dtype: bool)
# Before Sailing
#  Series([], Name: Sailing, dtype: bool)
# After Sailing
#  Series([], Name: Sailing, dtype: bool)
# Before Sandbox
#  Series([], Name: Sandbox, dtype: bool)
# After Sandbox
#  Series([], Name: Sandbox, dtype: bool)
# Before Satire
#  Series([], Name: Satire, dtype: bool)
# After Satire
#  Series([], Name: Satire, dtype: bool)
# Before Sci-fi
#  Series([], Name: Sci-fi, dtype: bool)
# After Sci-fi
#  Series([], Name: Sci-fi, dtype: bool)
# Before Science
#  Series([], Name: Science, dtype: bool)
# After Science
#  Series([], Name: Science, dtype: bool)
# Before Score Attack
#  Series([], Name: Score Attack, dtype: bool)
# After Score Attack
#  Series([], Name: Score Attack, dtype: bool)
# Before Sequel
#  Series([], Name: Sequel, dtype: bool)
# After Sequel
#  Series([], Name: Sequel, dtype: bool)
# Before Sexual Content
#  Series([], Name: Sexual Content, dtype: bool)
# After Sexual Content
#  Series([], Name: Sexual Content, dtype: bool)
# Before Shoot 'Em Up
#  Series([], Name: Shoot 'Em Up, dtype: bool)
# After Shoot 'Em Up
#  Series([], Name: Shoot 'Em Up, dtype: bool)
# Before Shooter
#  Series([], Name: Shooter, dtype: bool)
# After Shooter
#  Series([], Name: Shooter, dtype: bool)
# Before Short
#  Series([], Name: Short, dtype: bool)
# After Short
#  Series([], Name: Short, dtype: bool)
# Before Side Scroller
#  Series([], Name: Side Scroller, dtype: bool)
# After Side Scroller
#  Series([], Name: Side Scroller, dtype: bool)
# Before Silent Protagonist
#  Series([], Name: Silent Protagonist, dtype: bool)
# After Silent Protagonist
#  Series([], Name: Silent Protagonist, dtype: bool)
# Before Simulation
#  Series([], Name: Simulation, dtype: bool)
# After Simulation
#  Series([], Name: Simulation, dtype: bool)
# Before Singleplayer
#  Series([], Name: Singleplayer, dtype: bool)
# After Singleplayer
#  Series([], Name: Singleplayer, dtype: bool)
# Before Skateboarding
#  Series([], Name: Skateboarding, dtype: bool)
# After Skateboarding
#  Series([], Name: Skateboarding, dtype: bool)
# Before Skating
#  Series([], Name: Skating, dtype: bool)
# After Skating
#  Series([], Name: Skating, dtype: bool)
# Before Sniper
#  Series([], Name: Sniper, dtype: bool)
# After Sniper
#  Series([], Name: Sniper, dtype: bool)
# Before Snow
#  Series([], Name: Snow, dtype: bool)
# After Snow
#  Series([], Name: Snow, dtype: bool)
# Before Soccer
#  Series([], Name: Soccer, dtype: bool)
# After Soccer
#  Series([], Name: Soccer, dtype: bool)
# Before Social Deduction
#  Series([], Name: Social Deduction, dtype: bool)
# After Social Deduction
#  Series([], Name: Social Deduction, dtype: bool)
# Before Sokoban
#  Series([], Name: Sokoban, dtype: bool)
# After Sokoban
#  Series([], Name: Sokoban, dtype: bool)
# Before Solitaire
#  Series([], Name: Solitaire, dtype: bool)
# After Solitaire
#  Series([], Name: Solitaire, dtype: bool)
# Before Souls-like
#  Series([], Name: Souls-like, dtype: bool)
# After Souls-like
#  Series([], Name: Souls-like, dtype: bool)
# Before Space
#  Series([], Name: Space, dtype: bool)
# After Space
#  Series([], Name: Space, dtype: bool)
# Before Space Sim
#  Series([], Name: Space Sim, dtype: bool)
# After Space Sim
#  Series([], Name: Space Sim, dtype: bool)
# Before Spaceships
#  Series([], Name: Spaceships, dtype: bool)
# After Spaceships
#  Series([], Name: Spaceships, dtype: bool)
# Before Spectacle fighter
#  Series([], Name: Spectacle fighter, dtype: bool)
# After Spectacle fighter
#  Series([], Name: Spectacle fighter, dtype: bool)
# Before Spelling
#  Series([], Name: Spelling, dtype: bool)
# After Spelling
#  Series([], Name: Spelling, dtype: bool)
# Before Split Screen
#  Series([], Name: Split Screen, dtype: bool)
# After Split Screen
#  Series([], Name: Split Screen, dtype: bool)
# Before Sports
#  Series([], Name: Sports, dtype: bool)
# After Sports
#  Series([], Name: Sports, dtype: bool)
# Before Star Trek
#  Series([], Name: Star Trek, dtype: bool)
# After Star Trek
#  Series([], Name: Star Trek, dtype: bool)
# Before Star Wars
#  Series([], Name: Star Wars, dtype: bool)
# After Star Wars
#  Series([], Name: Star Wars, dtype: bool)
# Before Stealth
#  Series([], Name: Stealth, dtype: bool)
# After Stealth
#  Series([], Name: Stealth, dtype: bool)
# Before Steam Machine
#  Series([], Name: Steam Machine, dtype: bool)
# After Steam Machine
#  Series([], Name: Steam Machine, dtype: bool)
# Before Steampunk
#  Series([], Name: Steampunk, dtype: bool)
# After Steampunk
#  Series([], Name: Steampunk, dtype: bool)
# Before Story Rich
#  Series([], Name: Story Rich, dtype: bool)
# After Story Rich
#  Series([], Name: Story Rich, dtype: bool)
# Before Strategy
#  Series([], Name: Strategy, dtype: bool)
# After Strategy
#  Series([], Name: Strategy, dtype: bool)
# Before Strategy RPG
#  Series([], Name: Strategy RPG, dtype: bool)
# After Strategy RPG
#  Series([], Name: Strategy RPG, dtype: bool)
# Before Stylized
#  Series([], Name: Stylized, dtype: bool)
# After Stylized
#  Series([], Name: Stylized, dtype: bool)
# Before Submarine
#  Series([], Name: Submarine, dtype: bool)
# After Submarine
#  Series([], Name: Submarine, dtype: bool)
# Before Superhero
#  Series([], Name: Superhero, dtype: bool)
# After Superhero
#  Series([], Name: Superhero, dtype: bool)
# Before Supernatural
#  Series([], Name: Supernatural, dtype: bool)
# After Supernatural
#  Series([], Name: Supernatural, dtype: bool)
# Before Surreal
#  Series([], Name: Surreal, dtype: bool)
# After Surreal
#  Series([], Name: Surreal, dtype: bool)
# Before Survival
#  Series([], Name: Survival, dtype: bool)
# After Survival
#  Series([], Name: Survival, dtype: bool)
# Before Survival Horror
#  Series([], Name: Survival Horror, dtype: bool)
# After Survival Horror
#  Series([], Name: Survival Horror, dtype: bool)
# Before Swordplay
#  Series([], Name: Swordplay, dtype: bool)
# After Swordplay
#  Series([], Name: Swordplay, dtype: bool)
# Before Tabletop
#  Series([], Name: Tabletop, dtype: bool)
# After Tabletop
#  Series([], Name: Tabletop, dtype: bool)
# Before Tactical
#  Series([], Name: Tactical, dtype: bool)
# After Tactical
#  Series([], Name: Tactical, dtype: bool)
# Before Tactical RPG
#  Series([], Name: Tactical RPG, dtype: bool)
# After Tactical RPG
#  Series([], Name: Tactical RPG, dtype: bool)
# Before Tanks
#  Series([], Name: Tanks, dtype: bool)
# After Tanks
#  Series([], Name: Tanks, dtype: bool)
# Before Team-Based
#  Series([], Name: Team-Based, dtype: bool)
# After Team-Based
#  Series([], Name: Team-Based, dtype: bool)
# Before Tennis
#  Series([], Name: Tennis, dtype: bool)
# After Tennis
#  Series([], Name: Tennis, dtype: bool)
# Before Text-Based
#  Series([], Name: Text-Based, dtype: bool)
# After Text-Based
#  Series([], Name: Text-Based, dtype: bool)
# Before Third Person
#  Series([], Name: Third Person, dtype: bool)
# After Third Person
#  Series([], Name: Third Person, dtype: bool)
# Before Third-Person Shooter
#  Series([], Name: Third-Person Shooter, dtype: bool)
# After Third-Person Shooter
#  Series([], Name: Third-Person Shooter, dtype: bool)
# Before Thriller
#  Series([], Name: Thriller, dtype: bool)
# After Thriller
#  Series([], Name: Thriller, dtype: bool)
# Before Time Attack
#  Series([], Name: Time Attack, dtype: bool)
# After Time Attack
#  Series([], Name: Time Attack, dtype: bool)
# Before Time Management
#  Series([], Name: Time Management, dtype: bool)
# After Time Management
#  Series([], Name: Time Management, dtype: bool)
# Before Time Manipulation
#  Series([], Name: Time Manipulation, dtype: bool)
# After Time Manipulation
#  Series([], Name: Time Manipulation, dtype: bool)
# Before Time Travel
#  Series([], Name: Time Travel, dtype: bool)
# After Time Travel
#  Series([], Name: Time Travel, dtype: bool)
# Before Top-Down
#  Series([], Name: Top-Down, dtype: bool)
# After Top-Down
#  Series([], Name: Top-Down, dtype: bool)
# Before Top-Down Shooter
#  Series([], Name: Top-Down Shooter, dtype: bool)
# After Top-Down Shooter
#  Series([], Name: Top-Down Shooter, dtype: bool)
# Before Touch-Friendly
#  Series([], Name: Touch-Friendly, dtype: bool)
# After Touch-Friendly
#  Series([], Name: Touch-Friendly, dtype: bool)
# Before Tower Defense
#  Series([], Name: Tower Defense, dtype: bool)
# After Tower Defense
#  Series([], Name: Tower Defense, dtype: bool)
# Before TrackIR
#  Series([], Name: TrackIR, dtype: bool)
# After TrackIR
#  Series([], Name: TrackIR, dtype: bool)
# Before Trading
#  Series([], Name: Trading, dtype: bool)
# After Trading
#  Series([], Name: Trading, dtype: bool)
# Before Trading Card Game
#  Series([], Name: Trading Card Game, dtype: bool)
# After Trading Card Game
#  Series([], Name: Trading Card Game, dtype: bool)
# Before Traditional Roguelike
#  Series([], Name: Traditional Roguelike, dtype: bool)
# After Traditional Roguelike
#  Series([], Name: Traditional Roguelike, dtype: bool)
# Before Trains
#  Series([], Name: Trains, dtype: bool)
# After Trains
#  Series([], Name: Trains, dtype: bool)
# Before Transhumanism
#  Series([], Name: Transhumanism, dtype: bool)
# After Transhumanism
#  Series([], Name: Transhumanism, dtype: bool)
# Before Transportation
#  Series([], Name: Transportation, dtype: bool)
# After Transportation
#  Series([], Name: Transportation, dtype: bool)
# Before Trivia
#  Series([], Name: Trivia, dtype: bool)
# After Trivia
#  Series([], Name: Trivia, dtype: bool)
# Before Turn-Based
#  Series([], Name: Turn-Based, dtype: bool)
# After Turn-Based
#  Series([], Name: Turn-Based, dtype: bool)
# Before Turn-Based Combat
#  Series([], Name: Turn-Based Combat, dtype: bool)
# After Turn-Based Combat
#  Series([], Name: Turn-Based Combat, dtype: bool)
# Before Turn-Based Strategy
#  Series([], Name: Turn-Based Strategy, dtype: bool)
# After Turn-Based Strategy
#  Series([], Name: Turn-Based Strategy, dtype: bool)
# Before Turn-Based Tactics
#  Series([], Name: Turn-Based Tactics, dtype: bool)
# After Turn-Based Tactics
#  Series([], Name: Turn-Based Tactics, dtype: bool)
# Before Tutorial
#  Series([], Name: Tutorial, dtype: bool)
# After Tutorial
#  Series([], Name: Tutorial, dtype: bool)
# Before Twin Stick Shooter
#  Series([], Name: Twin Stick Shooter, dtype: bool)
# After Twin Stick Shooter
#  Series([], Name: Twin Stick Shooter, dtype: bool)
# Before Typing
#  Series([], Name: Typing, dtype: bool)
# After Typing
#  Series([], Name: Typing, dtype: bool)
# Before Underground
#  Series([], Name: Underground, dtype: bool)
# After Underground
#  Series([], Name: Underground, dtype: bool)
# Before Underwater
#  Series([], Name: Underwater, dtype: bool)
# After Underwater
#  Series([], Name: Underwater, dtype: bool)
# Before Unforgiving
#  Series([], Name: Unforgiving, dtype: bool)
# After Unforgiving
#  Series([], Name: Unforgiving, dtype: bool)
# Before VR
#  Series([], Name: VR, dtype: bool)
# After VR
#  Series([], Name: VR, dtype: bool)
# Before Vampire
#  Series([], Name: Vampire, dtype: bool)
# After Vampire
#  Series([], Name: Vampire, dtype: bool)
# Before Vehicular Combat
#  Series([], Name: Vehicular Combat, dtype: bool)
# After Vehicular Combat
#  Series([], Name: Vehicular Combat, dtype: bool)
# Before Villain Protagonist
#  Series([], Name: Villain Protagonist, dtype: bool)
# After Villain Protagonist
#  Series([], Name: Villain Protagonist, dtype: bool)
# Before Violent
#  Series([], Name: Violent, dtype: bool)
# After Violent
#  Series([], Name: Violent, dtype: bool)
# Before Visual Novel
#  Series([], Name: Visual Novel, dtype: bool)
# After Visual Novel
#  Series([], Name: Visual Novel, dtype: bool)
# Before Voice Control
#  Series([], Name: Voice Control, dtype: bool)
# After Voice Control
#  Series([], Name: Voice Control, dtype: bool)
# Before Voxel
#  Series([], Name: Voxel, dtype: bool)
# After Voxel
#  Series([], Name: Voxel, dtype: bool)
# Before Walking Simulator
#  Series([], Name: Walking Simulator, dtype: bool)
# After Walking Simulator
#  Series([], Name: Walking Simulator, dtype: bool)
# Before War
#  Series([], Name: War, dtype: bool)
# After War
#  Series([], Name: War, dtype: bool)
# Before Wargame
#  Series([], Name: Wargame, dtype: bool)
# After Wargame
#  Series([], Name: Wargame, dtype: bool)
# Before Warhammer 40K
#  Series([], Name: Warhammer 40K, dtype: bool)
# After Warhammer 40K
#  Series([], Name: Warhammer 40K, dtype: bool)
# Before Well-Written
#  Series([], Name: Well-Written, dtype: bool)
# After Well-Written
#  Series([], Name: Well-Written, dtype: bool)
# Before Werewolves
#  Series([], Name: Werewolves, dtype: bool)
# After Werewolves
#  Series([], Name: Werewolves, dtype: bool)
# Before Western
#  Series([], Name: Western, dtype: bool)
# After Western
#  Series([], Name: Western, dtype: bool)
# Before Word Game
#  Series([], Name: Word Game, dtype: bool)
# After Word Game
#  Series([], Name: Word Game, dtype: bool)
# Before World War I
#  Series([], Name: World War I, dtype: bool)
# After World War I
#  Series([], Name: World War I, dtype: bool)
# Before World War II
#  Series([], Name: World War II, dtype: bool)
# After World War II
#  Series([], Name: World War II, dtype: bool)
# Before Wrestling
#  Series([], Name: Wrestling, dtype: bool)
# After Wrestling
#  Series([], Name: Wrestling, dtype: bool)
# Before Zombies
#  Series([], Name: Zombies, dtype: bool)
# After Zombies
#  Series([], Name: Zombies, dtype: bool)
# Before eSports
#  Series([], Name: eSports, dtype: bool)
# After eSports
#  Series([], Name: eSports, dtype: bool)
# Before Arabic
#  Series([], Name: Arabic, dtype: bool)
# After Arabic
#  Series([], Name: Arabic, dtype: bool)
# Before Bulgarian
#  Series([], Name: Bulgarian, dtype: bool)
# After Bulgarian
#  Series([], Name: Bulgarian, dtype: bool)
# Before Czech
#  Series([], Name: Czech, dtype: bool)
# After Czech
#  Series([], Name: Czech, dtype: bool)
# Before Danish
#  Series([], Name: Danish, dtype: bool)
# After Danish
#  Series([], Name: Danish, dtype: bool)
# Before Dutch
#  Series([], Name: Dutch, dtype: bool)
# After Dutch
#  Series([], Name: Dutch, dtype: bool)
# Before Finnish
#  Series([], Name: Finnish, dtype: bool)
# After Finnish
#  Series([], Name: Finnish, dtype: bool)
# Before French
#  Series([], Name: French, dtype: bool)
# After French
#  Series([], Name: French, dtype: bool)
# Before German
#  Series([], Name: German, dtype: bool)
# After German
#  Series([], Name: German, dtype: bool)
# Before Greek
#  Series([], Name: Greek, dtype: bool)
# After Greek
#  Series([], Name: Greek, dtype: bool)
# Before Hungarian
#  Series([], Name: Hungarian, dtype: bool)
# After Hungarian
#  Series([], Name: Hungarian, dtype: bool)
# Before Italian
#  Series([], Name: Italian, dtype: bool)
# After Italian
#  Series([], Name: Italian, dtype: bool)
# Before Japanese
#  Series([], Name: Japanese, dtype: bool)
# After Japanese
#  Series([], Name: Japanese, dtype: bool)
# Before Korean
#  Series([], Name: Korean, dtype: bool)
# After Korean
#  Series([], Name: Korean, dtype: bool)
# Before Norwegian
#  Series([], Name: Norwegian, dtype: bool)
# After Norwegian
#  Series([], Name: Norwegian, dtype: bool)
# Before Polish
#  Series([], Name: Polish, dtype: bool)
# After Polish
#  Series([], Name: Polish, dtype: bool)
# Before Portuguese
#  Series([], Name: Portuguese, dtype: bool)
# After Portuguese
#  Series([], Name: Portuguese, dtype: bool)
# Before Romanian
#  Series([], Name: Romanian, dtype: bool)
# After Romanian
#  Series([], Name: Romanian, dtype: bool)
# Before Russian
#  Series([], Name: Russian, dtype: bool)
# After Russian
#  Series([], Name: Russian, dtype: bool)
# Before Swedish
#  Series([], Name: Swedish, dtype: bool)
# After Swedish
#  Series([], Name: Swedish, dtype: bool)
# Before Thai
#  Series([], Name: Thai, dtype: bool)
# After Thai
#  Series([], Name: Thai, dtype: bool)
# Before Turkish
#  Series([], Name: Turkish, dtype: bool)
# After Turkish
#  Series([], Name: Turkish, dtype: bool)
# Before Ukrainian
#  Series([], Name: Ukrainian, dtype: bool)
# After Ukrainian
#  Series([], Name: Ukrainian, dtype: bool)
# Before Vietnamese
#  Series([], Name: Vietnamese, dtype: bool)
# After Vietnamese
#  Series([], Name: Vietnamese, dtype: bool)
#        Metacritic Indie      Presence        Memory  ReleaseDate Soundtrack  \
# count        2157  2157  2.157000e+03   2157.000000  2157.000000       2157
# unique          4     2           NaN           NaN          NaN          2
# top          Good  True           NaN           NaN          NaN      False
# freq         1116  1209           NaN           NaN          NaN       2145
# mean          NaN   NaN  3.379322e+05   2541.908338  2012.654723        NaN
# std           NaN   NaN  3.838362e+05   2034.309192     4.634999        NaN
# min           NaN   NaN  0.000000e+00      2.000000  1993.000000        NaN
# 25%           NaN   NaN  2.060800e+04   1000.000000  2010.000000        NaN
# 50%           NaN   NaN  1.483020e+05   2000.000000  2014.000000        NaN
# 75%           NaN   NaN  6.362310e+05   4000.000000  2016.000000        NaN
# max           NaN   NaN  1.009588e+06  16000.000000  2020.000000        NaN
#
#         OriginalCost  DiscountedCost Controller  Achievements  ...  Norwegian  \
# count    2157.000000     2157.000000       2157   2157.000000  ...       2157
# unique           NaN             NaN          3           NaN  ...          2
# top              NaN             NaN       True           NaN  ...      False
# freq             NaN             NaN       1170           NaN  ...       2069
# mean       14.614659        0.106300        NaN     53.694019  ...        NaN
# std        11.651505        1.372147        NaN     59.101082  ...        NaN
# min         0.000000        0.000000        NaN      0.000000  ...        NaN
# 25%         6.990000        0.000000        NaN      2.000000  ...        NaN
# 50%        10.990000        0.000000        NaN     36.000000  ...        NaN
# 75%        19.990000        0.000000        NaN     78.000000  ...        NaN
# max        72.770000       44.990000        NaN    310.000000  ...        NaN
#
#        Polish Portuguese Romanian Russian Swedish   Thai  Turkish  Ukrainian  \
# count    2157       2157     2157    2157    2157   2157     2157       2157
# unique      2          2        2       2       2      2        2          2
# top     False      False    False   False   False  False    False      False
# freq     1581       2000     2115    1272    2063   2112     1994       2089
# mean      NaN        NaN      NaN     NaN     NaN    NaN      NaN        NaN
# std       NaN        NaN      NaN     NaN     NaN    NaN      NaN        NaN
# min       NaN        NaN      NaN     NaN     NaN    NaN      NaN        NaN
# 25%       NaN        NaN      NaN     NaN     NaN    NaN      NaN        NaN
# 50%       NaN        NaN      NaN     NaN     NaN    NaN      NaN        NaN
# 75%       NaN        NaN      NaN     NaN     NaN    NaN      NaN        NaN
# max       NaN        NaN      NaN     NaN     NaN    NaN      NaN        NaN
#
#         Vietnamese
# count         2157
# unique           2
# top          False
# freq          2142
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN
#
# [11 rows x 445 columns]

# %%
column = data.columns.get_loc('Metacritic')
y = data.iloc[:,column]
X = data.loc[:, data.columns != 'Metacritic']

# %%
#from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=109)

# %% [markdown]
# ## Voting scheme

# %%
from sklearn.model_selection import cross_val_score
#from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

cv=50

clf1 = GaussianNB()

params = {'n_neighbors':list(range(1,30,2)), 'weights':('distance','uniform')}
knc = KNeighborsClassifier()
clf = GridSearchCV(knc, param_grid=params,cv=cv,n_jobs=-1)  # If cv is integer, by default is Stratifyed 
clf.fit(X, y)
print("Best Params fo Knn=",clf.best_params_, "Accuracy=", clf.best_score_)
parval=clf.best_params_
clf2 = KNeighborsClassifier(n_neighbors=parval['n_neighbors'],weights=parval['weights'])

clf3 = DecisionTreeClassifier(criterion='entropy')


for clf, label in zip([clf1, clf2, clf3], ['Naive Bayes','Knn (3)', 'Dec. Tree', ]):
    scores = cross_val_score(clf, X, y, cv=cv, scoring='accuracy')
    print("Accuracy: %0.3f [%s]" % (scores.mean(), label))
# Out:
# Best Params fo Knn= {'n_neighbors': 15, 'weights': 'distance'} Accuracy= 0.5842177589852008
# Accuracy: 0.620 [Naive Bayes]
# Accuracy: 0.584 [Knn (3)]
# Accuracy: 0.653 [Dec. Tree]

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

eclf = VotingClassifier(estimators=[('nb', clf1), ('knn3', clf2), ('dt', clf3)], voting='hard')
scores = cross_val_score(eclf, X, y, cv=cv, scoring='accuracy')
print("Accuracy: %0.3f [%s]" % (scores.mean() , "Majority Voting"))
# Out:
# Accuracy: 0.654 [Majority Voting]

# %%
eclf = VotingClassifier(estimators=[('nb', clf1), ('knn3', clf2), ('dt', clf3)],voting='soft', weights=[2,1,2])
scores = cross_val_score(eclf, X, y, cv=cv, scoring='accuracy')
print("Accuracy: %0.3f [%s]" % (scores.mean(), "Weighted Voting"))
# Out:
# Accuracy: 0.668 [Weighted Voting]

# %% [markdown]
# ## Bagging

# %%
from sklearn.ensemble import BaggingClassifier

lb=[]
for nest in [1,2,5,10,20,50,100]:
    scores = cross_val_score(BaggingClassifier(base_estimator=DecisionTreeClassifier(),n_estimators=nest), X, y, cv=cv, scoring='accuracy')
    print("Accuracy: %0.3f [%s]" % (scores.mean(), nest))
    lb.append(scores.mean())

lb2=[]    
print()
for nest in [1,2,5,10,20,50,100]:
    scores = cross_val_score(BaggingClassifier(base_estimator=DecisionTreeClassifier(),n_estimators=nest,max_features=0.35), X, y, cv=cv, scoring='accuracy')
    print("Accuracy: %0.3f [%s]" % (scores.mean(), nest))
    lb2.append(scores.mean())
# Out:
# Accuracy: 0.628 [1]
# Accuracy: 0.614 [2]
# Accuracy: 0.684 [5]
# Accuracy: 0.724 [10]

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

lrf=[]
for nest in [1,2,5,10,20,50,100]:
    scores = cross_val_score(RandomForestClassifier(n_estimators=nest,n_jobs=-1), X, y, cv=cv, scoring='accuracy', n_jobs=-1)
    print("Accuracy: %0.3f [%s]" % (scores.mean(), nest))
    lrf.append(scores.mean())

# %%
from sklearn.ensemble import ExtraTreesClassifier

lext=[]
for nest in [1,2,5,10,20,50,100]:
    scores = cross_val_score(ExtraTreesClassifier(n_estimators=nest,n_jobs=-1), X, y, cv=cv, scoring='accuracy', n_jobs=-1)
    print("Accuracy: %0.3f [%s]" % (scores.mean(), nest))
    lext.append(scores.mean())

# %% [markdown]
# ## Boosting

# %%
from sklearn.ensemble import AdaBoostClassifier

lboo=[]
for nest in [1,2,5,10,20,50,100]:
    scores = cross_val_score(AdaBoostClassifier(n_estimators=nest,n_jobs=-1), X, y, cv=cv, scoring='accuracy')
    print("Accuracy: %0.3f [%s]" % (scores.mean(), nest))
    lboo.append(scores.mean())

# %%
from sklearn.ensemble import AdaBoostClassifier

lboodt=[]
for nest in [1,2,5,10,20,50,100]:
    scores = cross_val_score(AdaBoostClassifier(DecisionTreeClassifier(max_depth=5),n_estimators=nest), X, y, cv=cv, scoring='accuracy')
    print("Accuracy: %0.3f [%s]" % (scores.mean(), nest))
    lboodt.append(scores.mean())

# %%
from sklearn.ensemble import GradientBoostingClassifier

lgbboo=[]
for nest in [1,2,5,10,20,50,100]:
    scores = cross_val_score(GradientBoostingClassifier(n_estimators=nest), X, y, cv=cv, scoring='accuracy')
    print("Accuracy: %0.3f [%s]" % (scores.mean(), nest))
    lgbboo.append(scores.mean())

# %%
import  matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot([1,2,5,10,20,50,100],lb,label="Bagging DT")
plt.plot([1,2,5,10,20,50,100],lb2,label="Bagging DT forced variance")
plt.plot([1,2,5,10,20,50,100],lrf,label="Random Forest")
plt.plot([1,2,5,10,20,50,100],lext,label="Extra Trees")
plt.plot([1,2,5,10,20,50,100],lboo,label="AdaBoost Dec.Stumps")
plt.plot([1,2,5,10,20,50,100],lboodt,label="AdaBoost DT")
plt.plot([1,2,5,10,20,50,100],lgbboo,label="Gradient Boosting")
plt.legend(loc='lower right')

plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot([1,2,5,10,20,50,100],lb,label="Bagging DT")
plt.plot([1,2,5,10,20,50,100],lb2,label="Bagging DT forced variance")
plt.plot([1,2,5,10,20,50,100],lrf,label="Random Forest")
plt.plot([1,2,5,10,20,50,100],lext,label="Extra Trees")
plt.plot([1,2,5,10,20,50,100],lboo,label="AdaBoost Dec.Stumps")
plt.plot([1,2,5,10,20,50,100],lboodt,label="AdaBoost DT")
plt.plot([1,2,5,10,20,50,100],lgbboo,label="Gradient Boosting")
plt.legend(loc='lower right')
plt.xlim(10,200)
plt.ylim(0.90,0.96)
plt.show()

# %% [markdown]
# ## Feature Selection with Forests of trees

# %%
clf = RandomForestClassifier(n_estimators=100)
clf = clf.fit(X, y)
print(clf.feature_importances_)

# %%
from sklearn.feature_selection import SelectFromModel

model = SelectFromModel(clf, prefit=True, threshold=0.05)
X_new = model.transform(X)
print(X_new.shape)

print(np.mean(cross_val_score(KNeighborsClassifier(), X=X, y=y, cv=cv, scoring='accuracy')))
print(np.mean(cross_val_score(KNeighborsClassifier(), X=X_new, y=y, cv=cv, scoring='accuracy')))

# %%
thresholds=clf.feature_importances_

l=[]
lparval=[]
for threshold in thresholds:
    model = SelectFromModel(clf, prefit=True, threshold=threshold)
    X_new = model.transform(X)
    params = {'n_neighbors':list(range(1,30,2)), 'weights':('distance','uniform')}
    knc = KNeighborsClassifier()
    clf2 = GridSearchCV(knc, param_grid=params,cv=cv,n_jobs=-1)  # If cv is integer, by default is Stratifyed 
    clf2.fit(X, y)
    parval=clf2.best_params_
    clf3 = KNeighborsClassifier(n_neighbors=parval['n_neighbors'],weights=parval['weights'])
    acc = np.mean(cross_val_score(clf3, X=X_new, y=y, cv=cv, scoring='accuracy'))
    l.append(acc)
    lparval.append(parval)
    
plt.scatter(thresholds,l)
plt.show()

print('Best threshold: ',thresholds[np.argmax(l)])

# %%
parval=lparval[np.argmax(l)]
model = SelectFromModel(clf, prefit=True, threshold=thresholds[np.argmax(l)])
X_new = model.transform(X)
print(X_new.shape)

print('Original: ', np.mean(cross_val_score(KNeighborsClassifier(n_neighbors=1), X=X, y=y, cv=cv, scoring='accuracy')))
print('With FS: ', np.mean(cross_val_score(KNeighborsClassifier(n_neighbors=parval['n_neighbors'],weights=parval['weights']), X=X_new, y=y, cv=cv, scoring='accuracy')))
